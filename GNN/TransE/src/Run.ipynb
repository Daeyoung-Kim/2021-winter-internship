# %% [markdown]
# # Directory Setup

# %% [markdown]
# This directory setup is adaptable for google colab.
#
# If you run this code in local, you can skip this part.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/TransE/src
# Out:
# /content/drive/MyDrive/TransE/src

# %% [markdown]
# # Run

# %% [markdown]
# Default data directory is in umls dataset.

# %%
# !python main.py --data_dir '/content/drive/MyDrive/TransE/src/data/umls/' --embedding_dim 5 --score_func 'L2' --batch_size 100 --max_epoch 100 --eval_freq 100
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:111: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Namespace(batch_size=100, ckpt_dir='../ckpt/', data_dir='/content/drive/MyDrive/TransE/src/data/umls/', embedding_dim=5, eval_freq=100, learning_rate=0.001, margin_value=1.0, max_epoch=100, n_generator=24, n_rank_calculator=24, score_func='L2', summary_dir='../summary/')
# -----Loading entity dict-----
# #entity: 135
# -----Loading relation dict-----
# #relation: 49
# -----Loading training triples-----
# #training triple: 5469
# -----Loading validation triples-----
# #validation triple: 608
# -----Loading test triples------
# #test triple: 675
# ...

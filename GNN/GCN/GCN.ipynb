# %%
# Environment Setup
# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-1.10.0+cu113.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-1.10.0+cu113.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch_geometric.transforms as T

from torch_geometric.datasets import Planetoid
from torch_geometric.nn import MessagePassing
from torch_geometric.utils import add_self_loops, degree

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
# Setting
args = {
    'device': device,
    "dataset": "Cora",
    'hidden_dim': 16,
    'lr': 0.01,
    'weight_decay': 5e-4,
    'epochs': 200
}

# %%
# Load the data
dataset = Planetoid(root='./', name=args['dataset'], transform=T.NormalizeFeatures())
data = dataset[0].to(device)
data
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708])

# %%
# Implement simple GCNConv Layer with pytorch MessagePassing
class GCNLayer(MessagePassing):
  def __init__(self, input_dim, output_dim):
    # aggr: how to aggregate message of each node    
    super(GCNLayer, self).__init__(aggr='add')

    self.input_dim = input_dim
    self.output_dim = output_dim
    self.lin = nn.Linear(input_dim, output_dim).to(device)

  def forward(self, X, edge_index):

    edge_index, _ = add_self_loops(edge_index, num_nodes = X.shape[0])
    x = self.lin(X)

    row, col = edge_index
    deg_mat = degree(row, x.shape[0], dtype=x.dtype)
    deg_inv_sqrt_mat = deg_mat.pow(-0.5)
    norm = deg_inv_sqrt_mat[row] * deg_inv_sqrt_mat[col]

    return self.propagate(edge_index, size=(x.shape[0], x.shape[0]),
                          x = x, norm = norm)
    
    def message(self, X_j):
      return norm.view(-1, 1) * X_j

    # Update node embedding
    def update(self, aggr_output):
      return aggr_output

# %%
# Model
class GCN(nn.Module):
  def __init__(self):
    super().__init__()
    self.conv1 = GCNLayer(dataset.num_node_features, args['hidden_dim'])
    self.conv2 = GCNLayer(args['hidden_dim'], dataset.num_classes)

  def forward(self, data):
    x, edge_index = data.x, data.edge_index

    x = self.conv1(x, edge_index)
    x = F.relu(x)
    x = F.dropout(x, training=self.training)
    x = self.conv2(x, edge_index)

    return F.log_softmax(x, dim=1)

# %%
# learning
model = GCN().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'], weight_decay=args['weight_decay'])

def train():
  model.train()
  optimizer.zero_grad()
  out = model(data)
  loss = F.nll_loss(out[data.train_mask], data.y[data.train_mask])
  loss.backward()
  optimizer.step()

# %%
@torch.no_grad()
def test():
  model.eval()
  out, accuracy = model(data), []
  for _, mask in data('train_mask','val_mask', 'test_mask'):
    pred = out[mask].max(1)[1]
    acc = pred.eq(data.y[mask]).sum() / mask.sum()
    accuracy.append(acc)
  return accuracy

# %%
for epoch in range(args['epochs']):
  train()
  train_acc, val_acc, test_acc = test()
  
  print('Epoch: {:02d},'.format(epoch+1),
        'train_acc: {:.4f},'.format(train_acc.item()),
        'val_acc: {:.4f},'.format(val_acc.item()),
        'test_acc: {:.4f}'.format(test_acc.item()))
# Out:
# Epoch: 01, train_acc: 0.1143, val_acc: 0.1840, test_acc: 0.1760
# Epoch: 02, train_acc: 0.1500, val_acc: 0.1600, test_acc: 0.1410
# Epoch: 03, train_acc: 0.1571, val_acc: 0.1580, test_acc: 0.1410
# Epoch: 04, train_acc: 0.2429, val_acc: 0.2220, test_acc: 0.2090
# Epoch: 05, train_acc: 0.3143, val_acc: 0.2900, test_acc: 0.2770
# Epoch: 06, train_acc: 0.3571, val_acc: 0.3000, test_acc: 0.2920
# Epoch: 07, train_acc: 0.4214, val_acc: 0.3540, test_acc: 0.3510
# Epoch: 08, train_acc: 0.6500, val_acc: 0.4860, test_acc: 0.5200
# Epoch: 09, train_acc: 0.7214, val_acc: 0.5560, test_acc: 0.5800
# Epoch: 10, train_acc: 0.7714, val_acc: 0.5900, test_acc: 0.5910
# Epoch: 11, train_acc: 0.7857, val_acc: 0.6000, test_acc: 0.5910
# Epoch: 12, train_acc: 0.8000, val_acc: 0.6140, test_acc: 0.5970
# Epoch: 13, train_acc: 0.8286, val_acc: 0.6300, test_acc: 0.6100
# Epoch: 14, train_acc: 0.8571, val_acc: 0.6420, test_acc: 0.6260
# Epoch: 15, train_acc: 0.8786, val_acc: 0.6820, test_acc: 0.6670
# Epoch: 16, train_acc: 0.8929, val_acc: 0.6820, test_acc: 0.6850
# Epoch: 17, train_acc: 0.8786, val_acc: 0.6900, test_acc: 0.6920
# Epoch: 18, train_acc: 0.8786, val_acc: 0.7100, test_acc: 0.6960
# Epoch: 19, train_acc: 0.8857, val_acc: 0.7060, test_acc: 0.7020
# Epoch: 20, train_acc: 0.8857, val_acc: 0.6940, test_acc: 0.6930
# Epoch: 21, train_acc: 0.9000, val_acc: 0.6920, test_acc: 0.6970
# Epoch: 22, train_acc: 0.9071, val_acc: 0.7000, test_acc: 0.6960
# Epoch: 23, train_acc: 0.9214, val_acc: 0.7000, test_acc: 0.6980
# Epoch: 24, train_acc: 0.9286, val_acc: 0.7120, test_acc: 0.7070
# Epoch: 25, train_acc: 0.9429, val_acc: 0.7060, test_acc: 0.7050
# Epoch: 26, train_acc: 0.9429, val_acc: 0.7040, test_acc: 0.7090
# Epoch: 27, train_acc: 0.9429, val_acc: 0.7100, test_acc: 0.7090
# Epoch: 28, train_acc: 0.9429, val_acc: 0.7160, test_acc: 0.7110
# Epoch: 29, train_acc: 0.9500, val_acc: 0.7260, test_acc: 0.7180
# Epoch: 30, train_acc: 0.9429, val_acc: 0.7220, test_acc: 0.7200
# Epoch: 31, train_acc: 0.9429, val_acc: 0.7180, test_acc: 0.7190
# Epoch: 32, train_acc: 0.9500, val_acc: 0.7220, test_acc: 0.7170
# Epoch: 33, train_acc: 0.9500, val_acc: 0.7180, test_acc: 0.7170
# Epoch: 34, train_acc: 0.9643, val_acc: 0.7100, test_acc: 0.7200
# Epoch: 35, train_acc: 0.9714, val_acc: 0.7240, test_acc: 0.7240
# Epoch: 36, train_acc: 0.9714, val_acc: 0.7240, test_acc: 0.7200
# Epoch: 37, train_acc: 0.9786, val_acc: 0.7260, test_acc: 0.7180
# Epoch: 38, train_acc: 0.9786, val_acc: 0.7280, test_acc: 0.7170
# Epoch: 39, train_acc: 0.9857, val_acc: 0.7260, test_acc: 0.7140
# Epoch: 40, train_acc: 0.9857, val_acc: 0.7160, test_acc: 0.7130
# Epoch: 41, train_acc: 0.9857, val_acc: 0.7060, test_acc: 0.7020
# Epoch: 42, train_acc: 0.9857, val_acc: 0.7080, test_acc: 0.7030
# Epoch: 43, train_acc: 0.9857, val_acc: 0.7060, test_acc: 0.7090
# Epoch: 44, train_acc: 0.9857, val_acc: 0.7120, test_acc: 0.7100
# Epoch: 45, train_acc: 0.9857, val_acc: 0.7220, test_acc: 0.7120
# Epoch: 46, train_acc: 0.9857, val_acc: 0.7360, test_acc: 0.7170
# Epoch: 47, train_acc: 0.9857, val_acc: 0.7420, test_acc: 0.7200
# Epoch: 48, train_acc: 0.9857, val_acc: 0.7380, test_acc: 0.7340
# Epoch: 49, train_acc: 0.9929, val_acc: 0.7400, test_acc: 0.7320
# Epoch: 50, train_acc: 0.9929, val_acc: 0.7360, test_acc: 0.7340
# Epoch: 51, train_acc: 0.9929, val_acc: 0.7320, test_acc: 0.7380
# Epoch: 52, train_acc: 0.9929, val_acc: 0.7280, test_acc: 0.7310
# Epoch: 53, train_acc: 0.9929, val_acc: 0.7300, test_acc: 0.7290
# Epoch: 54, train_acc: 0.9929, val_acc: 0.7280, test_acc: 0.7240
# Epoch: 55, train_acc: 0.9929, val_acc: 0.7280, test_acc: 0.7250
# Epoch: 56, train_acc: 0.9929, val_acc: 0.7300, test_acc: 0.7250
# Epoch: 57, train_acc: 0.9929, val_acc: 0.7260, test_acc: 0.7210
# Epoch: 58, train_acc: 0.9929, val_acc: 0.7220, test_acc: 0.7140
# Epoch: 59, train_acc: 0.9929, val_acc: 0.7200, test_acc: 0.7120
# Epoch: 60, train_acc: 0.9929, val_acc: 0.7240, test_acc: 0.7170
# Epoch: 61, train_acc: 0.9929, val_acc: 0.7220, test_acc: 0.7170
# Epoch: 62, train_acc: 0.9929, val_acc: 0.7240, test_acc: 0.7180
# Epoch: 63, train_acc: 0.9929, val_acc: 0.7300, test_acc: 0.7150
# Epoch: 64, train_acc: 0.9929, val_acc: 0.7400, test_acc: 0.7210
# Epoch: 65, train_acc: 1.0000, val_acc: 0.7400, test_acc: 0.7230
# Epoch: 66, train_acc: 1.0000, val_acc: 0.7540, test_acc: 0.7300
# Epoch: 67, train_acc: 1.0000, val_acc: 0.7560, test_acc: 0.7310
# Epoch: 68, train_acc: 1.0000, val_acc: 0.7540, test_acc: 0.7310
# Epoch: 69, train_acc: 1.0000, val_acc: 0.7520, test_acc: 0.7370
# Epoch: 70, train_acc: 1.0000, val_acc: 0.7460, test_acc: 0.7380
# Epoch: 71, train_acc: 1.0000, val_acc: 0.7500, test_acc: 0.7360
# Epoch: 72, train_acc: 1.0000, val_acc: 0.7600, test_acc: 0.7370
# Epoch: 73, train_acc: 1.0000, val_acc: 0.7620, test_acc: 0.7400
# Epoch: 74, train_acc: 1.0000, val_acc: 0.7540, test_acc: 0.7410
# Epoch: 75, train_acc: 1.0000, val_acc: 0.7580, test_acc: 0.7460
# Epoch: 76, train_acc: 1.0000, val_acc: 0.7520, test_acc: 0.7470
# Epoch: 77, train_acc: 1.0000, val_acc: 0.7480, test_acc: 0.7460
# Epoch: 78, train_acc: 1.0000, val_acc: 0.7420, test_acc: 0.7430
# Epoch: 79, train_acc: 1.0000, val_acc: 0.7420, test_acc: 0.7410
# Epoch: 80, train_acc: 1.0000, val_acc: 0.7400, test_acc: 0.7380
# Epoch: 81, train_acc: 1.0000, val_acc: 0.7480, test_acc: 0.7390
# Epoch: 82, train_acc: 1.0000, val_acc: 0.7460, test_acc: 0.7360
# Epoch: 83, train_acc: 1.0000, val_acc: 0.7440, test_acc: 0.7340
# Epoch: 84, train_acc: 1.0000, val_acc: 0.7460, test_acc: 0.7260
# Epoch: 85, train_acc: 1.0000, val_acc: 0.7500, test_acc: 0.7260
# Epoch: 86, train_acc: 1.0000, val_acc: 0.7480, test_acc: 0.7230
# Epoch: 87, train_acc: 1.0000, val_acc: 0.7420, test_acc: 0.7230
# Epoch: 88, train_acc: 1.0000, val_acc: 0.7420, test_acc: 0.7190
# Epoch: 89, train_acc: 1.0000, val_acc: 0.7420, test_acc: 0.7260
# Epoch: 90, train_acc: 1.0000, val_acc: 0.7480, test_acc: 0.7280
# Epoch: 91, train_acc: 1.0000, val_acc: 0.7520, test_acc: 0.7300
# Epoch: 92, train_acc: 1.0000, val_acc: 0.7580, test_acc: 0.7300
# Epoch: 93, train_acc: 1.0000, val_acc: 0.7580, test_acc: 0.7330
# Epoch: 94, train_acc: 1.0000, val_acc: 0.7540, test_acc: 0.7330
# Epoch: 95, train_acc: 1.0000, val_acc: 0.7520, test_acc: 0.7380
# Epoch: 96, train_acc: 1.0000, val_acc: 0.7500, test_acc: 0.7380
# Epoch: 97, train_acc: 1.0000, val_acc: 0.7480, test_acc: 0.7350
# Epoch: 98, train_acc: 1.0000, val_acc: 0.7480, test_acc: 0.7370
# Epoch: 99, train_acc: 1.0000, val_acc: 0.7440, test_acc: 0.7360
# Epoch: 100, train_acc: 1.0000, val_acc: 0.7480, test_acc: 0.7370
# Epoch: 101, train_acc: 1.0000, val_acc: 0.7440, test_acc: 0.7360
# Epoch: 102, train_acc: 1.0000, val_acc: 0.7480, test_acc: 0.7340
# Epoch: 103, train_acc: 1.0000, val_acc: 0.7540, test_acc: 0.7260
# Epoch: 104, train_acc: 1.0000, val_acc: 0.7480, test_acc: 0.7260
# Epoch: 105, train_acc: 1.0000, val_acc: 0.7500, test_acc: 0.7260
# Epoch: 106, train_acc: 1.0000, val_acc: 0.7500, test_acc: 0.7270
# Epoch: 107, train_acc: 1.0000, val_acc: 0.7460, test_acc: 0.7310
# Epoch: 108, train_acc: 1.0000, val_acc: 0.7440, test_acc: 0.7310
# Epoch: 109, train_acc: 1.0000, val_acc: 0.7420, test_acc: 0.7340
# Epoch: 110, train_acc: 1.0000, val_acc: 0.7380, test_acc: 0.7320
# Epoch: 111, train_acc: 1.0000, val_acc: 0.7440, test_acc: 0.7330
# Epoch: 112, train_acc: 1.0000, val_acc: 0.7440, test_acc: 0.7350
# Epoch: 113, train_acc: 1.0000, val_acc: 0.7480, test_acc: 0.7340
# Epoch: 114, train_acc: 1.0000, val_acc: 0.7480, test_acc: 0.7380
# Epoch: 115, train_acc: 1.0000, val_acc: 0.7560, test_acc: 0.7380
# Epoch: 116, train_acc: 1.0000, val_acc: 0.7540, test_acc: 0.7390
# Epoch: 117, train_acc: 1.0000, val_acc: 0.7540, test_acc: 0.7450
# Epoch: 118, train_acc: 1.0000, val_acc: 0.7540, test_acc: 0.7430
# Epoch: 119, train_acc: 1.0000, val_acc: 0.7580, test_acc: 0.7410
# Epoch: 120, train_acc: 1.0000, val_acc: 0.7580, test_acc: 0.7410
# Epoch: 121, train_acc: 1.0000, val_acc: 0.7580, test_acc: 0.7380
# Epoch: 122, train_acc: 1.0000, val_acc: 0.7600, test_acc: 0.7420
# Epoch: 123, train_acc: 1.0000, val_acc: 0.7540, test_acc: 0.7390
# Epoch: 124, train_acc: 1.0000, val_acc: 0.7540, test_acc: 0.7370
# Epoch: 125, train_acc: 1.0000, val_acc: 0.7420, test_acc: 0.7360
# Epoch: 126, train_acc: 1.0000, val_acc: 0.7400, test_acc: 0.7390
# Epoch: 127, train_acc: 1.0000, val_acc: 0.7360, test_acc: 0.7350
# Epoch: 128, train_acc: 1.0000, val_acc: 0.7360, test_acc: 0.7300
# Epoch: 129, train_acc: 1.0000, val_acc: 0.7340, test_acc: 0.7280
# Epoch: 130, train_acc: 1.0000, val_acc: 0.7360, test_acc: 0.7350
# Epoch: 131, train_acc: 1.0000, val_acc: 0.7460, test_acc: 0.7370
# Epoch: 132, train_acc: 1.0000, val_acc: 0.7480, test_acc: 0.7340
# Epoch: 133, train_acc: 1.0000, val_acc: 0.7460, test_acc: 0.7360
# Epoch: 134, train_acc: 1.0000, val_acc: 0.7420, test_acc: 0.7330
# Epoch: 135, train_acc: 1.0000, val_acc: 0.7400, test_acc: 0.7320
# Epoch: 136, train_acc: 1.0000, val_acc: 0.7420, test_acc: 0.7290
# Epoch: 137, train_acc: 1.0000, val_acc: 0.7420, test_acc: 0.7320
# Epoch: 138, train_acc: 1.0000, val_acc: 0.7420, test_acc: 0.7330
# Epoch: 139, train_acc: 1.0000, val_acc: 0.7380, test_acc: 0.7330
# Epoch: 140, train_acc: 1.0000, val_acc: 0.7340, test_acc: 0.7370
# Epoch: 141, train_acc: 1.0000, val_acc: 0.7440, test_acc: 0.7380
# Epoch: 142, train_acc: 1.0000, val_acc: 0.7440, test_acc: 0.7370
# Epoch: 143, train_acc: 1.0000, val_acc: 0.7440, test_acc: 0.7340
# Epoch: 144, train_acc: 1.0000, val_acc: 0.7400, test_acc: 0.7300
# Epoch: 145, train_acc: 1.0000, val_acc: 0.7400, test_acc: 0.7330
# Epoch: 146, train_acc: 1.0000, val_acc: 0.7340, test_acc: 0.7290
# Epoch: 147, train_acc: 1.0000, val_acc: 0.7320, test_acc: 0.7250
# Epoch: 148, train_acc: 1.0000, val_acc: 0.7360, test_acc: 0.7260
# Epoch: 149, train_acc: 1.0000, val_acc: 0.7400, test_acc: 0.7240
# Epoch: 150, train_acc: 1.0000, val_acc: 0.7340, test_acc: 0.7200
# Epoch: 151, train_acc: 1.0000, val_acc: 0.7260, test_acc: 0.7170
# Epoch: 152, train_acc: 1.0000, val_acc: 0.7300, test_acc: 0.7230
# Epoch: 153, train_acc: 1.0000, val_acc: 0.7280, test_acc: 0.7230
# Epoch: 154, train_acc: 1.0000, val_acc: 0.7380, test_acc: 0.7220
# Epoch: 155, train_acc: 1.0000, val_acc: 0.7400, test_acc: 0.7350
# Epoch: 156, train_acc: 1.0000, val_acc: 0.7480, test_acc: 0.7430
# Epoch: 157, train_acc: 1.0000, val_acc: 0.7460, test_acc: 0.7450
# Epoch: 158, train_acc: 1.0000, val_acc: 0.7380, test_acc: 0.7440
# Epoch: 159, train_acc: 1.0000, val_acc: 0.7320, test_acc: 0.7450
# Epoch: 160, train_acc: 1.0000, val_acc: 0.7380, test_acc: 0.7420
# Epoch: 161, train_acc: 1.0000, val_acc: 0.7380, test_acc: 0.7330
# Epoch: 162, train_acc: 1.0000, val_acc: 0.7220, test_acc: 0.7140
# Epoch: 163, train_acc: 1.0000, val_acc: 0.7160, test_acc: 0.7070
# Epoch: 164, train_acc: 1.0000, val_acc: 0.7080, test_acc: 0.6970
# Epoch: 165, train_acc: 1.0000, val_acc: 0.7040, test_acc: 0.6860
# Epoch: 166, train_acc: 1.0000, val_acc: 0.7020, test_acc: 0.6830
# Epoch: 167, train_acc: 1.0000, val_acc: 0.7060, test_acc: 0.6870
# Epoch: 168, train_acc: 1.0000, val_acc: 0.7120, test_acc: 0.6940
# Epoch: 169, train_acc: 1.0000, val_acc: 0.7140, test_acc: 0.7040
# Epoch: 170, train_acc: 1.0000, val_acc: 0.7160, test_acc: 0.7130
# Epoch: 171, train_acc: 1.0000, val_acc: 0.7120, test_acc: 0.7230
# Epoch: 172, train_acc: 1.0000, val_acc: 0.7380, test_acc: 0.7280
# Epoch: 173, train_acc: 1.0000, val_acc: 0.7420, test_acc: 0.7380
# Epoch: 174, train_acc: 1.0000, val_acc: 0.7420, test_acc: 0.7350
# Epoch: 175, train_acc: 1.0000, val_acc: 0.7360, test_acc: 0.7350
# Epoch: 176, train_acc: 1.0000, val_acc: 0.7400, test_acc: 0.7410
# Epoch: 177, train_acc: 1.0000, val_acc: 0.7380, test_acc: 0.7440
# Epoch: 178, train_acc: 1.0000, val_acc: 0.7380, test_acc: 0.7450
# Epoch: 179, train_acc: 1.0000, val_acc: 0.7380, test_acc: 0.7410
# Epoch: 180, train_acc: 1.0000, val_acc: 0.7480, test_acc: 0.7410
# Epoch: 181, train_acc: 1.0000, val_acc: 0.7460, test_acc: 0.7420
# Epoch: 182, train_acc: 1.0000, val_acc: 0.7460, test_acc: 0.7410
# Epoch: 183, train_acc: 1.0000, val_acc: 0.7520, test_acc: 0.7420
# Epoch: 184, train_acc: 1.0000, val_acc: 0.7520, test_acc: 0.7420
# Epoch: 185, train_acc: 1.0000, val_acc: 0.7540, test_acc: 0.7410
# Epoch: 186, train_acc: 1.0000, val_acc: 0.7580, test_acc: 0.7420
# Epoch: 187, train_acc: 1.0000, val_acc: 0.7580, test_acc: 0.7420
# Epoch: 188, train_acc: 1.0000, val_acc: 0.7540, test_acc: 0.7400
# Epoch: 189, train_acc: 1.0000, val_acc: 0.7560, test_acc: 0.7400
# Epoch: 190, train_acc: 1.0000, val_acc: 0.7560, test_acc: 0.7410
# Epoch: 191, train_acc: 1.0000, val_acc: 0.7480, test_acc: 0.7440
# Epoch: 192, train_acc: 1.0000, val_acc: 0.7500, test_acc: 0.7420
# Epoch: 193, train_acc: 1.0000, val_acc: 0.7400, test_acc: 0.7420
# Epoch: 194, train_acc: 1.0000, val_acc: 0.7360, test_acc: 0.7410
# Epoch: 195, train_acc: 1.0000, val_acc: 0.7320, test_acc: 0.7360
# Epoch: 196, train_acc: 1.0000, val_acc: 0.7260, test_acc: 0.7320
# Epoch: 197, train_acc: 1.0000, val_acc: 0.7240, test_acc: 0.7290
# Epoch: 198, train_acc: 1.0000, val_acc: 0.7220, test_acc: 0.7310
# Epoch: 199, train_acc: 1.0000, val_acc: 0.7260, test_acc: 0.7320
# Epoch: 200, train_acc: 1.0000, val_acc: 0.7340, test_acc: 0.7310
